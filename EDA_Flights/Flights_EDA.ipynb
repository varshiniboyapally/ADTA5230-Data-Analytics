# %%
# !pip3.9 install pandas
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "Spring 2024 Airline Dataset.xlsx"  # Update with correct path
xls = pd.ExcelFile(file_path)

# Load the dataset
df = pd.read_excel(xls, sheet_name="Dataset")

# Display the first few rows
df.tail(10)
# Out:
#       FlightID             Airline OriginAirport DestinationAirport  \
# 9990      9991     Delta Air Lines           ATL                HND
# 9991      9992  Southwest Airlines           DXB                CDG
# 9992      9993  Southwest Airlines           ORD                HND
# 9993      9994  Southwest Airlines           DFW                LHR
# 9994      9995            Emirates           ATL                LAX
# 9995      9996   American Airlines           LHR                DXB
# 9996      9997            Emirates           SIN                LAX
# 9997      9998     British Airways           DFW                DFW
# 9998      9999   American Airlines           JFK                HND
# 9999     10000            Emirates           ORD                SIN
#
#          Distance DateOfFlight  DayOfWeek  TimeOfDay  FlightDuration  \
# 9990  1080.887677   2022-07-25     Monday      Night        6.481212
# 9991  3063.967715   2021-07-30     Friday  Afternoon       11.041467
# ...
